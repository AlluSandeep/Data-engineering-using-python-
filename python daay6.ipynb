# %%
import random
import matplotlib.pyplot as plt
import numpy as np
samples=random.sample(range(1,1000),100)
mean=np.mean(samples)
samples1=[]
for x in samples:
  samples1.append(x-mean)
plt.hist(samples1)
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/sandeep/marveldata.csv')

# %%
df.head(2).T
# Out:
#                                             0  \
# page_id                                  1678
# name                Spider-Man (Peter Parker)
# urlslug           \/Spider-Man_(Peter_Parker)
# ID                            Secret Identity
# ALIGN                         Good Characters
# EYE                                Hazel Eyes
# HAIR                               Brown Hair
# SEX                           Male Characters
# GSM                                       NaN
# ALIVE                       Living Characters
# APPEARANCES                            4043.0
# FIRST APPEARANCE                       Aug-62
# Year                                   1962.0
#
#                                                   1
# page_id                                        7139
# name                Captain America (Steven Rogers)
# urlslug           \/Captain_America_(Steven_Rogers)
# ID                                  Public Identity
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16376 entries, 0 to 16375
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   page_id           16376 non-null  int64
#  1   name              16376 non-null  object
#  2   urlslug           16376 non-null  object
#  3   ID                12606 non-null  object
#  4   ALIGN             13564 non-null  object
#  5   EYE               6609 non-null   object
#  6   HAIR              12112 non-null  object
#  7   SEX               15522 non-null  object
#  8   GSM               90 non-null     object
#  9   ALIVE             16373 non-null  object
#  10  APPEARANCES       15280 non-null  float64
#  11  FIRST APPEARANCE  15561 non-null  object
#  12  Year              15561 non-null  float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.6+ MB

# %%
x=len(df['name'])
x
# Out:
# 16376

# %%
df['name']
# Out:
# 0                  Spider-Man (Peter Parker)
# 1            Captain America (Steven Rogers)
# 2        Wolverine (James \"Logan\" Howlett)
# 3          Iron Man (Anthony \"Tony\" Stark)
# 4                        Thor (Thor Odinson)
#                         ...
# 16371                     Ru'ach (Earth-616)
# 16372        Thane (Thanos' son) (Earth-616)
# 16373          Tinkerer (Skrull) (Earth-616)
# 16374         TK421 (Spiderling) (Earth-616)
# 16375                  Yologarch (Earth-616)
# Name: name, Length: 16376, dtype: object

# %%
df_char=df['SEX'].value_counts
print(df_char)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Male Characters
# 1        Male Characters
# 2        Male Characters
# 3        Male Characters
# 4        Male Characters
#               ...
# 16371    Male Characters
# 16372    Male Characters
# 16373    Male Characters
# 16374    Male Characters
# 16375                NaN
# Name: SEX, Length: 16376, dtype: object>

# %%
df_char=df.groupby(['SEX']).count()['name']
print(df_char)
# Out:
# SEX
# Agender Characters           45
# Female Characters          3837
# Genderfluid Characters        2
# Male Characters           11638
# Name: name, dtype: int64

# %%
male=df_char['Male Characters']/x
male
# Out:
# 0.7106741573033708

# %%
female=df_char['Female Characters']/x
female
# Out:
# 0.23430630190522717

# %%
hair=df.groupby(['HAIR']).count()['name']
print(hair)
# Out:
# HAIR
# Auburn Hair                78
# Bald                      838
# Black Hair               3755
# Blond Hair               1582
# Blue Hair                  56
# Bronze Hair                 1
# Brown Hair               2339
# Dyed Hair                   1
# Gold Hair                   8
# Green Hair                117
# Grey Hair                 531
# Light Brown Hair            6
# Magenta Hair                5
# No Hair                  1176
# Orange Hair                43
# Orange-brown Hair           3
# Pink Hair                  31
# Purple Hair                47
# Red Hair                  620
# Reddish Blond Hair          6
# Silver Hair                16
# Strawberry Blond Hair      47
# Variable Hair              32
# White Hair                754
# Yellow Hair                20
# Name: name, dtype: int64

# %%
red_hair=hair['Red Hair']/x
print(red_hair)
# Out:
# 0.03786028334147533

# %%
print(female*red_hair)
# Out:
# 0.008870902978825162

# %%
brown_hair=hair['Brown Hair']/x
print(brown_hair)
# Out:
# 0.14283097215437227

# %%
print(male*brown_hair)
print(female*brown_hair)
# Out:
# 0.10150628077262973
# 0.033466196883019446

# %%
white_hair=hair['White Hair']/x
print(white_hair)
# Out:
# 0.04604298974108451

# %%
print(male*white_hair)
print(female*white_hair)
# Out:
# 0.032721562933972985
# 0.010788162654893825

# %%
green_eyes=df[df=='Green Eyes'].EYE.count()
green_eyes
# Out:
# 613

# %%
female_char=df[df=='Female Characters'].SEX.count()
female_char
# Out:
# 3837

# %%
female_green_count=df[(df.SEX=='Female Characters')&(df.EYE=='Green Eyes')].SEX.count()
female_green_count
# Out:
# 268

# %%
male_green_count=df[(df.SEX=='Male Characters')&(df.EYE=='Green Eyes')].SEX.count()
male_green_count
# Out:
# 328

# %%
prob_female_green=female_green_count/x
prob_female_green
# Out:
# 0.016365412799218368

# %%
prob_male_green=male_green_count/x
prob_male_green
# Out:
# 0.020029311187103077

# %%
df1=pd.DataFrame({'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3'],'C':['C0','C1','C2','C3'],'D':['D0','D1','D2','D3']},index=[0,1,2,3])

# %%
df2=pd.DataFrame({'A':['A4','A5','A6','A7'],'B':['B4','B5','B6','B7'],'C':['C4','C5','C6','C7'],'D':['D4','D5','D6','D7']},index=[4,5,6,7])

# %%
df3=pd.DataFrame({'A':['A8','A9','A10','A11'],'B':['B8','B9','B10','B11'],'C':['C8','C9','C10','C11'],'D':['D8','D9','D10','D11']},index=[8,9,10,11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left=pd.DataFrame({'key':['K0','K1','K22','K33'],
                   'A':['A0','A1','A2','A3'],
                   'B':['B0','B1','B2','B3']})

# %%
right=pd.DataFrame({'key':['K0','K1','K2','K3'],
                    'C':['C0','C1','C2','C3'],
                    'D':['D0','D1','D2','D3']})

# %%
left
# Out:
#    key   A   B
# 0   K0  A0  B0
# 1   K1  A1  B1
# 2  K22  A2  B2
# 3   K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1

# %%
pd.merge(left,right,how='outer',on='key')
# Out:
#    key    A    B    C    D
# 0   K0   A0   B0   C0   D0
# 1   K1   A1   B1   C1   D1
# 2  K22   A2   B2  NaN  NaN
# 3  K33   A3   B3  NaN  NaN
# 4   K2  NaN  NaN   C2   D2
# 5   K3  NaN  NaN   C3   D3

# %%
pd.merge(left,right,how='left',on='key')
# Out:
#    key   A   B    C    D
# 0   K0  A0  B0   C0   D0
# 1   K1  A1  B1   C1   D1
# 2  K22  A2  B2  NaN  NaN
# 3  K33  A3  B3  NaN  NaN

# %%
pd.merge(left,right,how='right',on='key')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1   A1   B1  C1  D1
# 2  K2  NaN  NaN  C2  D2
# 3  K3  NaN  NaN  C3  D3

# %%
left1=pd.DataFrame({'key1':['K0','K0','K1','K2'],
                   'key2':['K0','K1','K0','K1'],
                   'A':['A0','A1','A2','A3'],
                   'B':['B0','B1','B2','B3']})
right1=pd.DataFrame({'key1':['K0','K1','K1','K2'],
                    'key2':['K0','K0','K0','K0'],
                    'C':['C0','C1','C2','C3'],
                    'D':['D0','D1','D2','D3']})

# %%
pd.merge(left1,right1,on=['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left1,right1,how='left',on=['key1','key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
pd.merge(left1,right1,how='right',on=['key1','key2'])
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
pd.merge(left1,right1,how='inner',on=['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left1,right1,how='outer',on=['key1','key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
import pandas as pd
import numpy as np
d={'a':list(range(4)),
   'b':list('ab.*'),
   'c':['a','b',np.nan,'d']}
d
# Out:
# {'a': [0, 1, 2, 3], 'b': ['a', 'b', '.', '*'], 'c': ['a', 'b', nan, 'd']}

# %%
df=pd.DataFrame(d)
df
# Out:
#    a  b    c
# 0  0  a    a
# 1  1  b    b
# 2  2  .  NaN
# 3  3  *    d

# %%
df['b']
# Out:
# 0    a
# 1    b
# 2    .
# 3    *
# Name: b, dtype: object

# %%
df.replace('.','',inplace=True)
df
# Out:
#    a  b    c
# 0  0  a    a
# 1  1  b    b
# 2  2     NaN
# 3  3  *    d

# %%
df.replace('',np.nan,inplace=True)
df
# Out:
#    a    b    c
# 0  0    a    a
# 1  1    b    b
# 2  2  NaN  NaN
# 3  3    *    d

# %%
df.fillna(10)
# Out:
#    a   b   c
# 0  0   a   a
# 1  1   b   b
# 2  2  10  10
# 3  3   *   d

# %%
df.dropna()
# Out:
#    a  b  c
# 0  0  a  a
# 1  1  b  b
# 3  3  *  d

# %%
import pandas as pd
import numpy as np
d={'a':list(range(4)),
   'b':list('[]()'),
   'c':['a','b',np.nan,'d']}
d
# Out:
# {'a': [0, 1, 2, 3], 'b': ['[', ']', '(', ')'], 'c': ['a', 'b', nan, 'd']}

# %%
df=pd.DataFrame(d)
df
# Out:
#    a  b    c
# 0  0  [    a
# 1  1  ]    b
# 2  2  (  NaN
# 3  3  )    d
